# %%
import gp
import numpy as np
from importlib import reload
import h5py
import matplotlib.pylab as plt
import json
reload(gp)
# Out:
# <module 'gp' from '/home/luca/source/GP3/python/gp.py'>

# %%
# %matplotlib notebook
geo=gp.geometry((40,40,40),[(-2,2),(-2,2),(-2,2)])
r2=geo.positions(0)**2 + geo.positions(1)**2 + geo.positions(2)**2
y=(np.exp(-r2) + 0*1j).reshape(geo.shape[0],geo.shape[1],geo.shape[2],1)
wave=gp.wavefunction(geo,[y] ,name="phi" )
wave.save("phiTest")
wave2=gp.loadWavefunction("phiTest")

plt.plot(np.sqrt(r2.flatten()),wave2.phis[0].flatten())
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/luca/miniconda3/envs/py3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
